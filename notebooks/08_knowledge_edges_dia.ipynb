# %%
import pandas as pd

# %%
## Load data
triplets_dia = pd.concat([
    pd.read_csv("../../Scientific_Novelty_Detection/Triplets/Blogs/Dia_Blogs_triplets.csv"),
    pd.read_csv("../../Scientific_Novelty_Detection/Triplets/Novel_Papers/Dia2021_triplets.csv"),
    pd.read_csv("../../Scientific_Novelty_Detection/Triplets/SKG/Dia_triplets.csv")
], ignore_index=True)
filtered_df = pd.read_csv("../outputs/filtered_papers.csv")
paper_nodes = pd.read_csv("../outputs/paper_nodes_dia.csv")
entity_nodes = pd.read_csv("../outputs/entity_nodes.csv")

print("Triplets:", len(triplets_dia))
print("Filtered papers:", len(filtered_df))
print("Paper nodes:", len(paper_nodes))
print("Entities:", len(entity_nodes))
# Out:
# Triplets: 24619
# Filtered papers: 2628
# Paper nodes: 2628
# Entities: 108816

# %%
triplets_dia.rename({"paper_ID" : "paper_id"}, axis=1, inplace=True)

# %%
triplets_dia
# Out:
#        topic  paper_id  sentence_ID          info-unit                    sub  \
# 0      Blogs         0           23  ablation-analysis       hyper-parameters
# 1      Blogs         0           23  ablation-analysis  more powerful decoder
# 2      Blogs         0           23  ablation-analysis      ablation analysis
# 3      Blogs         0           59  ablation-analysis         tuned decoding
# 4      Blogs         0           59  ablation-analysis              ssa score
# ...      ...       ...          ...                ...                    ...
# 24614  Blogs         7          181            results                    top
# 24615  Blogs         7          181            results                results
# 24616  Blogs         7          189            results                  dstc1
# 24617  Blogs         7          189            results           outperformed
# 24618  Blogs         7          189            results                results
#
#                   pred                            obj  \
# 0      discovered that          more powerful decoder
# 1               key to  higher conversational quality
# 2               tuning               hyper-parameters
# 3             advances                      ssa score
# 4                   to                           79 %
# ...                ...                            ...
# 24614               in    dstc1 and dstc3 evaluations
# 24615              has      machine - learned methods
# 24616              has           sequential crf model
# 24617              has   static classifier approaches
# 24618               In                          dstc1
#
#                                                 triplets  pred_weights
# 0      hyper-parameters discovered that more powerful...      0.709181
# 1      more powerful decoder key to higher conversati...      0.592724
# 2              ablation analysis tuning hyper-parameters      0.820923
# 3                      tuned decoding advances ssa score      0.693804
# 4                                      ssa score to 79 %      0.526003
# ...                                                  ...           ...
# 24614                 top in dstc1 and dstc3 evaluations      0.557671
# 24615              results has machine - learned methods      0.492934
# 24616                     dstc1 has sequential crf model      0.571273
# 24617      outperformed has static classifier approaches      0.631077
# 24618                                   results In dstc1      0.516317
#
# [24619 rows x 9 columns]

# %%
triplets_dia.columns
# Out:
# Index(['topic', 'paper_id', 'sentence_ID', 'info-unit', 'sub', 'pred', 'obj',
#        'triplets', 'pred_weights'],
#       dtype='object')

# %%
filtered_dia = filtered_df[filtered_df["domain"] == "DIA"].copy()

paper_nodes_dia = paper_nodes[
    (paper_nodes["domain"] == "DIA")
].copy()

print("Filtered DIA papers:", len(filtered_dia))
print("Paper nodes DIA:", len(paper_nodes_dia))
# Out:
# Filtered DIA papers: 274
# Paper nodes DIA: 274

# %%
## BUILD local_paper_id → global_paper_id MAP
filtered_dia = filtered_df[filtered_df["domain"] == "DIA"].copy()

paper_nodes_dia = paper_nodes[
    (paper_nodes["domain"] == "DIA")
].copy()

print("Filtered DIA papers:", len(filtered_dia))
print("Paper nodes DIA:", len(paper_nodes_dia))
# Out:
# Filtered DIA papers: 274
# Paper nodes DIA: 274

# %%
# BUILD local_paper_id → global_paper_id MAP
local_to_global = dict(
    zip(filtered_dia["local_paper_id"], filtered_dia["global_paper_id"])
)

print("Local → Global mapping size:", len(local_to_global))
# Out:
# Local → Global mapping size: 231

# %%
# BUILD entity name → entity_id MAP
entity_map = dict(
    zip(entity_nodes["name"], entity_nodes["node_id"])
)

print("Entity mapping size:", len(entity_map))
# Out:
# Entity mapping size: 108816

# %%
# BUILD entity name → entity_id MAP
paper_year_map = dict(
    zip(paper_nodes_dia["node_id"], paper_nodes_dia["year"])
)

# %%
# CONSTRUCT KNOWLEDGE EDGES
knowledge_edges = []

missing_entities = 0
missing_papers = 0

for _, row in triplets_dia.iterrows():

    local_id = (row["paper_id"])   # ensure string match

    if local_id not in local_to_global:
        missing_papers += 1
        continue

    global_id = local_to_global[local_id]

    sub = str(row["sub"]).strip()
    pred = str(row["pred"]).strip()
    obj = str(row["obj"]).strip()

    # Normalize (must match entity_nodes cleaning)
    sub = sub.lower()
    obj = obj.lower()

    # SUB edge
    if sub in entity_map:
        knowledge_edges.append({
            "source": global_id,
            "target": entity_map[sub],
            "predicate": pred,
            "year": paper_year_map.get(global_id)
        })
    else:
        missing_entities += 1

    # OBJ edge
    if obj in entity_map:
        knowledge_edges.append({
            "source": global_id,
            "target": entity_map[obj],
            "predicate": pred,
            "year": paper_year_map.get(global_id)
        })
    else:
        missing_entities += 1

# %%
knowledge_edges
# Out:
# [{'source': 'SKG_DIA_0',
#   'target': 'E_4616a006d0',
#   'predicate': 'discovered that',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_ed84d47e33',
#   'predicate': 'discovered that',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_ed84d47e33',
#   'predicate': 'key to',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_250a0b27d0',
#   'predicate': 'key to',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_b12965637d',
#   'predicate': 'tuning',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_4616a006d0',
#   'predicate': 'tuning',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_68a81f19c9',
#   'predicate': 'advances',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_0221cdbe2a',
#   'predicate': 'advances',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_0221cdbe2a',
#   'predicate': 'to',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_b12965637d',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_261b1f06fb',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_b12965637d',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_75d8f8f392',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_aa8af3ebe1',
#   'predicate': 'between',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_c286b9545a',
#   'predicate': 'between',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_aa8af3ebe1',
#   'predicate': 'between',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_e606139573',
#   'predicate': 'between',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_541f98322e',
#   'predicate': 'crowd-sourced',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_8689b49376',
#   'predicate': 'crowd-sourced',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_8689b49376',
#   'predicate': 'with',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_36a844df3d',
#   'predicate': 'with',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_b2f5a14ef5',
#   'predicate': 'answer',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_f7290e4e72',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_b2f5a14ef5',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_873b2176f8',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_f00333c929',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_9e76d075c3',
#   'predicate': 'asked to use',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_4887c7fb10',
#   'predicate': 'asked to use',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_4887c7fb10',
#   'predicate': 'to judge',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_d1fc8eaf36',
#   'predicate': 'to judge',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_d1fc8eaf36',
#   'predicate': 'is',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_49704d431b',
#   'predicate': 'is',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_49704d431b',
#   'predicate': 'in',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_5c18ef7277',
#   'predicate': 'in',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_50f5e9df7f',
#   'predicate': "'s",
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_7c6483ddcd',
#   'predicate': "'s",
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_724e205892',
#   'predicate': 'should be',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_5bbf2d6725',
#   'predicate': 'should be',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_50f5e9df7f',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_10bf3b4221',
#   'predicate': 'collect',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_f7640d0503',
#   'predicate': 'individual conversation turns through',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_06eaeb413e',
#   'predicate': 'uncertainty of',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_67fbfa4ece',
#   'predicate': 'uncertainty of',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_06eaeb413e',
#   'predicate': 'represents',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_4271dc7b67',
#   'predicate': 'represents',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_46893f419f',
#   'predicate': 'minimize',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_06eaeb413e',
#   'predicate': 'minimize',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_85799ff4e5',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_46893f419f',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_59a2e7f36a',
#   'predicate': 'used for',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_c185ddac8b',
#   'predicate': 'used for',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_59a2e7f36a',
#   'predicate': 'organized as',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_f6b6a3fa6f',
#   'predicate': 'organized as',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_f6b6a3fa6f',
#   'predicate': 'where',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_90cc5462e7',
#   'predicate': 'where',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_85799ff4e5',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_59a2e7f36a',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_9179796085',
#   'predicate': 'with',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_11016d2849',
#   'predicate': 'with',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_11016d2849',
#   'predicate': 'of',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_5c18ef7277',
#   'predicate': 'of',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_11016d2849',
#   'predicate': 'one path through',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_a356b066c4',
#   'predicate': 'one path through',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_85799ff4e5',
#   'predicate': 'extract',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_9179796085',
#   'predicate': 'extract',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_bb3aec0fdc',
#   'predicate': 'as',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_988598c2e7',
#   'predicate': 'as',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_b3a22d3e4f',
#   'predicate': 'to train',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_3d7fa3654b',
#   'predicate': 'to train',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_5c12243df5',
#   'predicate': 'within',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_5becdf3c92',
#   'predicate': 'within',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_85799ff4e5',
#   'predicate': 'choose',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_bb3aec0fdc',
#   'predicate': 'choose',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_9b9ad02089',
#   'predicate': 'trained on',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_67703fef18',
#   'predicate': 'trained on',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_67703fef18',
#   'predicate': 'ltered from',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_512ef4ea8f',
#   'predicate': 'ltered from',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_9b9ad02089',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_4ff11707c5',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_85799ff4e5',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_9b9ad02089',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_6ae8e62451',
#   'predicate': 'between',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_a116c012e4',
#   'predicate': 'between',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_fba99f718e',
#   'predicate': 'starts with',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_4958b35164',
#   'predicate': 'starts with',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_6ae8e62451',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_fba99f718e',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_a116c012e4',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_fba99f718e',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_85799ff4e5',
#   'predicate': 'to ensure',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_6ae8e62451',
#   'predicate': 'to ensure',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_01194e9a86',
#   'predicate': 'labeled by',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_9fe3b6d85b',
#   'predicate': 'labeled by',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_85799ff4e5',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_01194e9a86',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_d49b851093',
#   'predicate': 'with',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_d5bddcc106',
#   'predicate': 'with',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_d5bddcc106',
#   'predicate': 'such as',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_cab58848ef',
#   'predicate': 'such as',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_d5bddcc106',
#   'predicate': 'such as',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_c1f5914f0a',
#   'predicate': 'such as',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_d5bddcc106',
#   'predicate': 'such as',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_c2faa53b08',
#   'predicate': 'such as',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_7e2ccfa512',
#   'predicate': 'present',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_c286b9545a',
#   'predicate': 'present',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_7e2ccfa512',
#   'predicate': 'present',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_aec3d58230',
#   'predicate': 'present',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_c286b9545a',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_aec3d58230',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_20f35e630d',
#   'predicate': 'Towards',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_7e2ccfa512',
#   'predicate': 'Towards',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_20f35e630d',
#   'predicate': 'present',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_c286b9545a',
#   'predicate': 'present',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_dce31448f6',
#   'predicate': 'is',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_0af3ce8354',
#   'predicate': 'is',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_dce31448f6',
#   'predicate': 'end-to-end ,',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_0af3ce8354',
#   'predicate': 'end-to-end ,',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_7e21cc89a9',
#   'predicate': 'to',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_94b311f133',
#   'predicate': 'to',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_20f35e630d',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_dce31448f6',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_7c899632ce',
#   'predicate': 'discovered by',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_1ab15c58c7',
#   'predicate': 'discovered by',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_1ab15c58c7',
#   'predicate': 'to improve',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_06eaeb413e',
#   'predicate': 'to improve',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_45f996086d',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_7c899632ce',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_c286b9545a',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_7cbb46fe23',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_20f35e630d',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_c286b9545a',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_724a00e315',
#   'predicate': 'processing',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_69378e1bf4',
#   'predicate': 'processing',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_69378e1bf4',
#   'predicate': 'to help',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_c286b9545a',
#   'predicate': 'to help',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_c286b9545a',
#   'predicate': 'understand',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_dfe5da3565',
#   'predicate': 'understand',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_20f35e630d',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_724a00e315',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_3a6bdba8fb',
#   'predicate': 'uses',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_bb3ccd5881',
#   'predicate': 'uses',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_bb3ccd5881',
#   'predicate': 'to formulate',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_5377b8c74c',
#   'predicate': 'to formulate',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_20f35e630d',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_3a6bdba8fb',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_1a8ad3decc',
#   'predicate': 'captures',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_9838bcd554',
#   'predicate': 'captures',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_9838bcd554',
#   'predicate': 'for',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_ecd741180c',
#   'predicate': 'for',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_20f35e630d',
#   'predicate': 'design',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_7637523e07',
#   'predicate': 'design',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_d1fc8eaf36',
#   'predicate': 'makes',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_f5743daa1b',
#   'predicate': 'makes',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_724e205892',
#   'predicate': 'speci c to',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_12385eec39',
#   'predicate': 'speci c to',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_d1fc8eaf36',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_724e205892',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_f5743daa1b',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_724e205892',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_e64c313202',
#   'predicate': 'inconsistent with',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_b4ef240845',
#   'predicate': 'inconsistent with',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_e64c313202',
#   'predicate': 'inconsistent with',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_74409f763e',
#   'predicate': 'inconsistent with',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_74409f763e',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_b0ff0745de',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_53e61336bb',
#   'predicate': 'say',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_e64c313202',
#   'predicate': 'say',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_53e61336bb',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_11565c43b7',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_090193c0e9',
#   'predicate': 'is',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_58da31bf86',
#   'predicate': 'is',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_58da31bf86',
#   'predicate': 'to',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_ab3de8f476',
#   'predicate': 'to',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_aa58588162',
#   'predicate': 'than',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_12a032ce91',
#   'predicate': 'than',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_c286b9545a',
#   'predicate': 'conduct',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_59a2e7f36a',
#   'predicate': 'conduct',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_a6e1594699',
#   'predicate': 'than',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_06474d2c34',
#   'predicate': 'than',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_53e61336bb',
#   'predicate': 'show',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_c286b9545a',
#   'predicate': 'show',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_fa5f5cae6a',
#   'predicate': 'propose for',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_9d9d559955',
#   'predicate': 'propose for',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_fa5f5cae6a',
#   'predicate': 'called',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_1a8ad3decc',
#   'predicate': 'called',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_1a8ad3decc',
#   'predicate': 'captures',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_9838bcd554',
#   'predicate': 'captures',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_9838bcd554',
#   'predicate': 'for',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_fda5842514',
#   'predicate': 'for',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_53e61336bb',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_f867a4fdb0',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_53e61336bb',
#   'predicate': 'demonstrate',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_06eaeb413e',
#   'predicate': 'demonstrate',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_180885ecd2',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_787a1bdfbc',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_180885ecd2',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_c286b9545a',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_c286b9545a',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_53e61336bb',
#   'predicate': 'Compared to',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_180885ecd2',
#   'predicate': 'Compared to',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_53e61336bb',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_7637523e07',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_0f20cd73d9',
#   'predicate': 'rated as',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_17a6cf20f0',
#   'predicate': 'rated as',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_a9e44f57bd',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_0ea12e8bd2',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_e84afaab83',
#   'predicate': 'used in',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_5069f5b631',
#   'predicate': 'used in',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_53e61336bb',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_e84afaab83',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_ed03fea1aa',
#   'predicate': "ca n't get enough of",
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_f445e0417d',
#   'predicate': 'marked as',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_50f5e9df7f',
#   'predicate': "ca n't get enough of",
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_ed03fea1aa',
#   'predicate': "ca n't get enough of",
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_50f5e9df7f',
#   'predicate': 'marked as',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_f445e0417d',
#   'predicate': 'marked as',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_ed03fea1aa',
#   'predicate': 'marked as',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_f445e0417d',
#   'predicate': 'marked as',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_50f5e9df7f',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_f445e0417d',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_b7f27f6800',
#   'predicate': 'of',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_00f2b1ead3',
#   'predicate': 'of',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_b7f27f6800',
#   'predicate': 'is',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_8b9088d353',
#   'predicate': 'is',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_8452a89602',
#   'predicate': 'is',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_8b9088d353',
#   'predicate': 'is',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_8b9088d353',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_53e61336bb',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_b7f27f6800',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_c286b9545a',
#   'predicate': 'does',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_bdbebaae67',
#   'predicate': 'does',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_bdbebaae67',
#   'predicate': 'than',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_06474d2c34',
#   'predicate': 'than',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_06474d2c34',
#   'predicate': 'by',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_c36cc7d56d',
#   'predicate': 'by',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_c36cc7d56d',
#   'predicate': 'in terms of',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_6a623845b5',
#   'predicate': 'in terms of',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_53e61336bb',
#   'predicate': 'demonstrate',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_c286b9545a',
#   'predicate': 'demonstrate',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_53e61336bb',
#   'predicate': 'discover',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_06eaeb413e',
#   'predicate': 'discover',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_53e61336bb',
#   'predicate': 'lower',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_06eaeb413e',
#   'predicate': 'lower',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_53e61336bb',
#   'predicate': 'lower',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_06eaeb413e',
#   'predicate': 'lower',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_07e9cab9ae',
#   'predicate': 'compared with',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_cbf07d0fe0',
#   'predicate': 'compared with',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_07e9cab9ae',
#   'predicate': 'compared with',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_37b6900be7',
#   'predicate': 'compared with',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_53e61336bb',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_07e9cab9ae',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_e75cf97da9',
#   'predicate': 'referred to as',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_6f64fd0bbd',
#   'predicate': 'referred to as',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_e75cf97da9',
#   'predicate': 'achieves',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_06eaeb413e',
#   'predicate': 'achieves',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_e75cf97da9',
#   'predicate': 'translates to',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_0221cdbe2a',
#   'predicate': 'translates to',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_06eaeb413e',
#   'predicate': 'of',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_0221cdbe2a',
#   'predicate': 'of',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_53e61336bb',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_e75cf97da9',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_6a623845b5',
#   'predicate': 'achieved by',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_bfffbebc9d',
#   'predicate': 'achieved by',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_6a623845b5',
#   'predicate': 'of',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_0221cdbe2a',
#   'predicate': 'of',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_056029c2a5',
#   'predicate': 'achieved by',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_6a623845b5',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_0221cdbe2a',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_bfffbebc9d',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_0221cdbe2a',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_53e61336bb',
#   'predicate': 'Compared to',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_6a623845b5',
#   'predicate': 'Compared to',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_4def0e278d',
#   'predicate': 'improvements in',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_24b2d85eaf',
#   'predicate': 'improvements in',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_9c9420928b',
#   'predicate': 'associated with',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_04fdd11d03',
#   'predicate': 'associated with',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_04fdd11d03',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_9d5e9ccab6',
#   'predicate': 'has',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_53e61336bb',
#   'predicate': 'evaluating',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_0',
#   'target': 'E_9c9420928b',
#   'predicate': 'evaluating',
#   'year': 2019.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_fb7ff272df',
#   'predicate': 'generate',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_0ad424c92b',
#   'predicate': 'generate',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_7b5c448ce3',
#   'predicate': 'has',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_639bae9ac6',
#   'predicate': 'has',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_c445cbfe55',
#   'predicate': 'has',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_c85cec8c25',
#   'predicate': 'from',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_05c35aa57f',
#   'predicate': 'from',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_aa4f02a94c',
#   'predicate': 'crafted',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_4b9785d1d8',
#   'predicate': 'crafted',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_b575844c21',
#   'predicate': 'has',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_aa4f02a94c',
#   'predicate': 'has',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_1a5820b408',
#   'predicate': 'with',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_293b970116',
#   'predicate': 'with',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_1a5820b408',
#   'predicate': 'with',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_293b970116',
#   'predicate': 'with',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_1a5820b408',
#   'predicate': 'with',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_293b970116',
#   'predicate': 'with',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_293b970116',
#   'predicate': 'between',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_89759e1284',
#   'predicate': 'between',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_293b970116',
#   'predicate': 'between',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_4813991bf5',
#   'predicate': 'between',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_293b970116',
#   'predicate': 'between',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_4813991bf5',
#   'predicate': 'between',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_89759e1284',
#   'predicate': 'for',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_07f443f7aa',
#   'predicate': 'for',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_89759e1284',
#   'predicate': 'for',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_ce258fe0ec',
#   'predicate': 'for',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_89759e1284',
#   'predicate': 'for',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_ce258fe0ec',
#   'predicate': 'for',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_3080a111a2',
#   'predicate': 'with',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_293b970116',
#   'predicate': 'with',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_293b970116',
#   'predicate': 'between',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_4813991bf5',
#   'predicate': 'between',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_d04983a332',
#   'predicate': 'contains',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_1855d26fcd',
#   'predicate': 'contains',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_1855d26fcd',
#   'predicate': 'for',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_ce258fe0ec',
#   'predicate': 'for',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_4cd2ae1ec6',
#   'predicate': 'include',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_f58d07442d',
#   'predicate': 'include',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_4cd2ae1ec6',
#   'predicate': 'include',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_1a4325bd53',
#   'predicate': 'include',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_b575844c21',
#   'predicate': 'has',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_4cd2ae1ec6',
#   'predicate': 'has',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_7316de2727',
#   'predicate': 'by modeling',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_fc048f2cb7',
#   'predicate': 'by modeling',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_8fb56d9c45',
#   'predicate': 'in',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_12323b1523',
#   'predicate': 'in',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_c455af4e9c',
#   'predicate': 'has',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_4dcdb03e8f',
#   'predicate': 'has',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_1896519770',
#   'predicate': 'generate',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_e4128a54df',
#   'predicate': 'generate',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_6f6fe297ef',
#   'predicate': 'for',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_c185ddac8b',
#   'predicate': 'for',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_a653055885',
#   'predicate': 'constrained to',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_b20f5cc9c0',
#   'predicate': 'constrained to',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_fa48c7d544',
#   'predicate': 'is',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_d304ba20e9',
#   'predicate': 'is',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_aeef517a5c',
#   'predicate': 'called',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_5ac3ba8046',
#   'predicate': 'called',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_20f35e630d',
#   'predicate': 'has',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_fa48c7d544',
#   'predicate': 'has',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_a5d04c6f5a',
#   'predicate': 'trained',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_aa957be301',
#   'predicate': 'trained',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_a5d04c6f5a',
#   'predicate': 'plugged in',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_a455b431c1',
#   'predicate': 'plugged in',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_20f35e630d',
#   'predicate': 'has',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_a5d04c6f5a',
#   'predicate': 'has',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_4c8a1510ef',
#   'predicate': 'including',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_32707275e5',
#   'predicate': 'including',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_4c8a1510ef',
#   'predicate': 'including',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_09610f79db',
#   'predicate': 'including',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_4c8a1510ef',
#   'predicate': 'including',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_bc81f2e9b5',
#   'predicate': 'including',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_4c8a1510ef',
#   'predicate': 'including',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_7bde2048cd',
#   'predicate': 'including',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_78e6221f63',
#   'predicate': 'of',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_96f44244fd',
#   'predicate': 'of',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_96f44244fd',
#   'predicate': 'together with',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_1273c3b823',
#   'predicate': 'together with',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_20f35e630d',
#   'predicate': 'maps',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_78e6221f63',
#   'predicate': 'maps',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_9508d01293',
#   'predicate': 'projected into',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_acd828bd37',
#   'predicate': 'projected into',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_20f35e630d',
#   'predicate': 'has',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_9508d01293',
#   'predicate': 'has',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_1e9b75430a',
#   'predicate': 'projecting',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_cd4dd45910',
#   'predicate': 'projecting',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_cd4dd45910',
#   'predicate': 'into',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_52a4394d52',
#   'predicate': 'into',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_d1fc8eaf36',
#   'predicate': 'closest to',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_5c9ff1aae5',
#   'predicate': 'closest to',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_20f35e630d',
#   'predicate': 'has',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_1e9b75430a',
#   'predicate': 'has',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_97b212a7d7',
#   'predicate': 'by combining',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_b1f964d519',
#   'predicate': 'by combining',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_97b212a7d7',
#   'predicate': 'taking',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_65b0e2883c',
#   'predicate': 'taking',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_b1f964d519',
#   'predicate': 'of',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_10b3bbed74',
#   'predicate': 'of',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_b1f964d519',
#   'predicate': 'summing',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_b1f964d519',
#   'predicate': 'summing',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_b1f964d519',
#   'predicate': 'taking',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_65b0e2883c',
#   'predicate': 'taking',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_20f35e630d',
#   'predicate': 'created',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_97b212a7d7',
#   'predicate': 'created',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_e281d49ca0',
#   'predicate': 'together with',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_3443193ef6',
#   'predicate': 'together with',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_e281d49ca0',
#   'predicate': 'given as',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_a8aff967e1',
#   'predicate': 'given as',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_a8aff967e1',
#   'predicate': 'to',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_f94e67bbd6',
#   'predicate': 'to',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_f94e67bbd6',
#   'predicate': 'to classify',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_79571d6ce4',
#   'predicate': 'to classify',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_20f35e630d',
#   'predicate': 'has',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_e281d49ca0',
#   'predicate': 'has',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_7e1211c63c',
#   'predicate': 'given',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_8ae556a888',
#   'predicate': 'given',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_8ae556a888',
#   'predicate': 'to',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_fc4d19ee22',
#   'predicate': 'to',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_fc4d19ee22',
#   'predicate': 'plus',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_faa6e8a9a3',
#   'predicate': 'plus',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_faa6e8a9a3',
#   'predicate': 'from',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_3f3b694623',
#   'predicate': 'from',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_20f35e630d',
#   'predicate': 'framed as',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_7e1211c63c',
#   'predicate': 'framed as',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_faea2dcbd9',
#   'predicate': 'same as',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_cd69b4957f',
#   'predicate': 'same as',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_cd69b4957f',
#   'predicate': 'used in',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_59bd14aa2c',
#   'predicate': 'used in',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_cd69b4957f',
#   'predicate': 'extracted from',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_a43c1b0aa5',
#   'predicate': 'extracted from',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_4a58d03efc',
#   'predicate': 'refers to',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_5789df91f2',
#   'predicate': 'refers to',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_5789df91f2',
#   'predicate': 'xed for',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_433b048718',
#   'predicate': 'xed for',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_20f35e630d',
#   'predicate': 'has',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_faea2dcbd9',
#   'predicate': 'has',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_893b56e3cf',
#   'predicate': 'with',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_fdb766adca',
#   'predicate': 'with',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_53e61336bb',
#   'predicate': 'has',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_893b56e3cf',
#   'predicate': 'has',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_53e61336bb',
#   'predicate': 'has',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_989ff68ca1',
#   'predicate': 'has',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_53e61336bb',
#   'predicate': 'As',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_848a828993',
#   'predicate': 'As',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_18501ecb60',
#   'predicate': 'tend to be',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_cf62f67bba',
#   'predicate': 'tend to be',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_53e61336bb',
#   'predicate': 'has',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_18501ecb60',
#   'predicate': 'has',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_53e61336bb',
#   'predicate': 'choosing',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_efd125d030',
#   'predicate': 'choosing',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_582e215061',
#   'predicate': 'generate',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_69e506e974',
#   'predicate': 'generate',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_f9a9e6db8a',
#   'predicate': 'handle',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_4b354f756e',
#   'predicate': 'handle',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_53e61336bb',
#   'predicate': 'has',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_f9a9e6db8a',
#   'predicate': 'has',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_8c7b4c5d3c',
#   'predicate': 'from',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_6dad9d3b74',
#   'predicate': 'from',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_53e61336bb',
#   'predicate': 'take advantage of',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_8c7b4c5d3c',
#   'predicate': 'take advantage of',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_25a9ac406a',
#   'predicate': 'from',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_a34b12829e',
#   'predicate': 'from',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_25a9ac406a',
#   'predicate': 'to bootstrap',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_45029c9e5d',
#   'predicate': 'to bootstrap',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_84a0f3455d',
#   'predicate': 'has',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_25a9ac406a',
#   'predicate': 'has',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_53e61336bb',
#   'predicate': 'building',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_e622de29b9',
#   'predicate': 'building',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_6d61fcbbfc',
#   'predicate': 'by leveraging',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_c5c383e4cc',
#   'predicate': 'by leveraging',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_c5c383e4cc',
#   'predicate': 'able to',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_33c0478b99',
#   'predicate': 'able to',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_c05f6c2335',
#   'predicate': 'on',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_c5b8b6bf6d',
#   'predicate': 'on',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_33c0478b99',
#   'predicate': 'has',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_c05f6c2335',
#   'predicate': 'has',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_53e61336bb',
#   'predicate': 'has',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_6d61fcbbfc',
#   'predicate': 'has',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_fabcaa9787',
#   'predicate': 'to exhibit',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_1',
#   'target': 'E_1d3a23a943',
#   'predicate': 'to exhibit',
#   'year': 2018.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_4328ade470',
#   'predicate': 'chosen as',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_418c5509e2',
#   'predicate': 'chosen as',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_3ac340832f',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_05d6b981ca',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_2f30a774b6',
#   'predicate': 'using',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_3799b057ee',
#   'predicate': 'using',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_4328ade470',
#   'predicate': 'chosen as',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_418c5509e2',
#   'predicate': 'chosen as',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_3ac340832f',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_05d6b981ca',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_2f30a774b6',
#   'predicate': 'using',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_3799b057ee',
#   'predicate': 'using',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_6f205e849d',
#   'predicate': 'for',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_78805a221a',
#   'predicate': 'for',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_b575844c21',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_3658ff877f',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_c6b7ed918a',
#   'predicate': 'affect',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_9ff472352e',
#   'predicate': 'affect',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_d25007f323',
#   'predicate': 'create',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_b178e87f18',
#   'predicate': 'create',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_d25007f323',
#   'predicate': 'on',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_b178e87f18',
#   'predicate': 'on',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_d25007f323',
#   'predicate': 'role of',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_66207865e5',
#   'predicate': 'role of',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_b178e87f18',
#   'predicate': 'role of',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_66207865e5',
#   'predicate': 'role of',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_12fde26013',
#   'predicate': 'ask',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_d25007f323',
#   'predicate': 'create',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_b178e87f18',
#   'predicate': 'create',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_d25007f323',
#   'predicate': 'on',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_b178e87f18',
#   'predicate': 'on',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_d25007f323',
# ...
#   'target': 'E_17b7144937',
#   'predicate': 'training',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_78805a221a',
#   'predicate': 'obtained using',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_346b473abb',
#   'predicate': 'obtained using',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_346b473abb',
#   'predicate': 'from',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_1b68181644',
#   'predicate': 'from',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_cec315e3d0',
#   'predicate': 'during',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_c185ddac8b',
#   'predicate': 'during',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_472b3a5c6d',
#   'predicate': 'obtained using',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_346b473abb',
#   'predicate': 'obtained using',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_17b7144937',
#   'predicate': 'about',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_b45eb2669e',
#   'predicate': 'about',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_17b7144937',
#   'predicate': 'in form of',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_6ba8844da7',
#   'predicate': 'in form of',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_0f63bb9b5c',
#   'predicate': 'trained current question asked by',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_12fde26013',
#   'predicate': 'trained current question asked by',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_c185ddac8b',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_472b3a5c6d',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_20f35e630d',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_6f205e849d',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_53e61336bb',
#   'predicate': 'Link to',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_76e2a2b013',
#   'predicate': 'Link to',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_a189c633d9',
#   'predicate': 'Given',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_78805a221a',
#   'predicate': 'Given',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_a189c633d9',
#   'predicate': 'Given',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_5494af1f14',
#   'predicate': 'Given',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_a189c633d9',
#   'predicate': 'reply in',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_a6105c0a61',
#   'predicate': 'reply in',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_a189c633d9',
#   'predicate': 'reply in',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_a6105c0a61',
#   'predicate': 'reply in',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_a189c633d9',
#   'predicate': 'reply in',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_a189c633d9',
#   'predicate': 'reply in',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_4b99c13013',
#   'predicate': 'reply in',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_a189c633d9',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_a189c633d9',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_53e61336bb',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_a189c633d9',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_aa36dc6e81',
#   'predicate': 'is',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_308094a500',
#   'predicate': 'is',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_f9b11ed03c',
#   'predicate': 'function of',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_defe71ae77',
#   'predicate': 'function of',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_aa36dc6e81',
#   'predicate': 'is',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_308094a500',
#   'predicate': 'is',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_9aa10dd767',
#   'predicate': 'obtained',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_7e3f660480',
#   'predicate': 'reports',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_16cf885fd7',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_9aa10dd767',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_53e61336bb',
#   'predicate': 'On',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_16cf885fd7',
#   'predicate': 'On',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_cd36249706',
#   'predicate': 'tends to',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_4135789d2d',
#   'predicate': 'indication of',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_53e61336bb',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_cd36249706',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_bec4f6e9e5',
#   'predicate': 'tends to generate',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_01e549803b',
#   'predicate': 'tends to generate',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_bec4f6e9e5',
#   'predicate': 'tends to generate',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_53e61336bb',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_bec4f6e9e5',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_7cf57ac2d4',
#   'predicate': 'favours',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_ce4c68e85c',
#   'predicate': 'favours',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_7cf57ac2d4',
#   'predicate': 'favours',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_17b7144937',
#   'predicate': 'favours',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_53e61336bb',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_7cf57ac2d4',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_7cf57ac2d4',
#   'predicate': 'tends to generate',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_337eaeb215',
#   'predicate': 'tends to generate',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_7cf57ac2d4',
#   'predicate': 'uses',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_bd73295031',
#   'predicate': 'uses',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_53e61336bb',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_7cf57ac2d4',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_12fde26013',
#   'predicate': 'ask',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_a8cfde6331',
#   'predicate': 'about',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_53e61336bb',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_12fde26013',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_12fde26013',
#   'predicate': 'ask',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_a8cfde6331',
#   'predicate': 'about',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_53e61336bb',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_12fde26013',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_6794250387',
#   'predicate': 'grows at',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_6794250387',
#   'predicate': 'between',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_15bf100752',
#   'predicate': 'between',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_53e61336bb',
#   'predicate': 'Interesting Observations',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_12fde26013',
#   'predicate': 'uses',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_508ec3e2a4',
#   'predicate': 'uses',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_508ec3e2a4',
#   'predicate': 'like',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_d0886daf86',
#   'predicate': 'like',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_508ec3e2a4',
#   'predicate': 'early in',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_b24e976029',
#   'predicate': 'early in',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_d0886daf86',
#   'predicate': 'early in',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_b24e976029',
#   'predicate': 'early in',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_94a884f08b',
#   'predicate': 'to',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_7045686d3a',
#   'predicate': 'to',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_7045686d3a',
#   'predicate': 'like',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_6279c0716f',
#   'predicate': 'like',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_53e61336bb',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_12fde26013',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_724a00e315',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_53e61336bb',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_53e61336bb',
#   'predicate': 'Link to',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_76e2a2b013',
#   'predicate': 'Link to',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_a189c633d9',
#   'predicate': 'Given',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_78805a221a',
#   'predicate': 'Given',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_a189c633d9',
#   'predicate': 'Given',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_5494af1f14',
#   'predicate': 'Given',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_a189c633d9',
#   'predicate': 'reply in',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_a6105c0a61',
#   'predicate': 'reply in',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_a189c633d9',
#   'predicate': 'reply in',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_a6105c0a61',
#   'predicate': 'reply in',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_a189c633d9',
#   'predicate': 'reply in',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_a189c633d9',
#   'predicate': 'reply in',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_4b99c13013',
#   'predicate': 'reply in',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_a189c633d9',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_a189c633d9',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_53e61336bb',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_a189c633d9',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_9aa10dd767',
#   'predicate': 'obtained',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_7e3f660480',
#   'predicate': 'reports',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_16cf885fd7',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_9aa10dd767',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_53e61336bb',
#   'predicate': 'On',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_16cf885fd7',
#   'predicate': 'On',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_cd36249706',
#   'predicate': 'tends to',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_4135789d2d',
#   'predicate': 'indication of',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_53e61336bb',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_cd36249706',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_bec4f6e9e5',
#   'predicate': 'tends to generate',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_01e549803b',
#   'predicate': 'tends to generate',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_bec4f6e9e5',
#   'predicate': 'tends to generate',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_53e61336bb',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_bec4f6e9e5',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_7cf57ac2d4',
#   'predicate': 'favours',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_ce4c68e85c',
#   'predicate': 'favours',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_7cf57ac2d4',
#   'predicate': 'favours',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_17b7144937',
#   'predicate': 'favours',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_53e61336bb',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_7cf57ac2d4',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_7cf57ac2d4',
#   'predicate': 'tends to generate',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_337eaeb215',
#   'predicate': 'tends to generate',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_7cf57ac2d4',
#   'predicate': 'uses',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_bd73295031',
#   'predicate': 'uses',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_53e61336bb',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_7cf57ac2d4',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_12fde26013',
#   'predicate': 'ask',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_a8cfde6331',
#   'predicate': 'about',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_53e61336bb',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_12fde26013',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_12fde26013',
#   'predicate': 'ask',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_a8cfde6331',
#   'predicate': 'about',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_53e61336bb',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_12fde26013',
#   'predicate': 'has',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_6794250387',
#   'predicate': 'grows at',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_6794250387',
#   'predicate': 'between',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_15bf100752',
#   'predicate': 'between',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_53e61336bb',
#   'predicate': 'Interesting Observations',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_12fde26013',
#   'predicate': 'uses',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_508ec3e2a4',
#   'predicate': 'uses',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_508ec3e2a4',
#   'predicate': 'like',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_d0886daf86',
#   'predicate': 'like',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_508ec3e2a4',
#   'predicate': 'early in',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_b24e976029',
#   'predicate': 'early in',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_d0886daf86',
#   'predicate': 'early in',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_b24e976029',
#   'predicate': 'early in',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_94a884f08b',
#   'predicate': 'to',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_7045686d3a',
#   'predicate': 'to',
#   'year': 2020.0},
#  {'source': 'SKG_DIA_2',
#   'target': 'E_7045686d3a',
#   'predicate': 'like',
#   'year': 2020.0},
#  ...]

# %%
# Create DataFrame
knowledge_df = pd.DataFrame(knowledge_edges)

print("Total DIA knowledge edges:", len(knowledge_df))
print("Missing paper mappings:", missing_papers)
print("Missing entity mappings:", missing_entities)

print("Unique sources:", knowledge_df["source"].nunique())
print("Unique targets:", knowledge_df["target"].nunique())
# Out:
# Total DIA knowledge edges: 41561
# Missing paper mappings: 2470
# Missing entity mappings: 2737
# Unique sources: 231
# Unique targets: 13317

# %%
knowledge_df.to_csv("../outputs/knowledge_edges_dia.csv", index=False)

print("Saved knowledge_edges_dia.csv")
# Out:
# Saved knowledge_edges_dia.csv
